# %%
import numpy as np
import scipy
import mne
import sys
sys.path.insert(0,"../exercises/")
from matplotlib import pyplot as plt
import ccs_eeg_utils
from time_frequency_analysis import Tf_analysis

# %%
subjectId = '001'
bids_root = './local/bids'

# %%
tf = Tf_analysis(subjectId)

# %%
tf.time_frequency_analysis(bids_root)
# Out:
# Reading C:\Users\sayye\OneDrive\Desktop\college\PG\eeg_lecture\course_eeg_SS2022\Project\local\bids\sub-001\ses-P3\eeg\sub-001_ses-P3_task-P3_eeg.fdt
# Reading events from local\bids\sub-001\ses-P3\eeg\sub-001_ses-P3_task-P3_events.tsv.
# The event "response" refers to multiple event values. Creating hierarchical event names.
#     Renaming event: response -> response/202
#     Renaming event: response -> response/202
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
# ...
