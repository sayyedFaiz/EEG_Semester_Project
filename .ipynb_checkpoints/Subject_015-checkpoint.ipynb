# %%
from preprocess import Preprocess 
import mne

# %%
subjectId = '015'

# %%
s1 = Preprocess(subjectId)

# %%
s1.loadData()
# Out:
# Reading C:\Users\sayye\OneDrive\Desktop\college\PG\eeg_lecture\course_eeg_SS2022\Project\local\bids\sub-015\ses-P3\eeg\sub-015_ses-P3_task-P3_eeg.fdt
# Reading events from local\bids\sub-015\ses-P3\eeg\sub-015_ses-P3_task-P3_events.tsv.
# The event "response" refers to multiple event values. Creating hierarchical event names.
#     Renaming event: response -> response/202
#     Renaming event: response -> response/202
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
#     Renaming event: response -> response/201
# ...

# %%
# %matplotlib qt
s1.raw.plot(n_channels=len(s1.raw.ch_names))
# Out:
# Using matplotlib as 2D backend.
# <MNEBrowseFigure size 576x576 with 4 Axes>
# <MNEBrowseFigure size 576x576 with 4 Axes>

# %%
mne.set_eeg_reference(inst=s1.raw, ref_channels=["P9","P10"])
# Out:
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# (<RawEEGLAB | sub-015_ses-P3_task-P3_eeg.fdt, 33 x 372736 (364.0 s), ~93.9 MB, data loaded>,
#  array([-0.00131645, -0.00131879, -0.00132053, ..., -0.00285251,
#         -0.00285404, -0.00285221]))

# %%
s1.raw
# Out:
# <RawEEGLAB | sub-015_ses-P3_task-P3_eeg.fdt, 33 x 372736 (364.0 s), ~93.9 MB, data loaded>

# %%
s1.raw.filter(0.5, 50, fir_design='firwin')
# Out:
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 50 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 50.00 Hz
# - Upper transition bandwidth: 12.50 Hz (-6 dB cutoff frequency: 56.25 Hz)
# - Filter length: 6759 samples (6.601 s)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   3 out of   3 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   4 out of   4 | elapsed:    0.0s remaining:    0.0s
# ...

# %%
# %matplotlib qt
s1.raw.plot(n_channels=len(s1.raw.ch_names))
# Out:
# <MNEBrowseFigure size 1000x1000 with 4 Axes>
# Channels marked as bad:
# ['C5']

# %%
from autoreject import AutoReject

# %%
ar = AutoReject()
raw_cleaned, _ = ar.fit_transform(s1.raw)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-4c68156bbf5c> in <module>
#       1 ar = AutoReject()
# ----> 2 raw_cleaned, _ = ar.fit_transform(s1.raw)
#
# c:\users\sayye\appdata\local\programs\python\python39\lib\site-packages\autoreject\autoreject.py in fit_transform(self, epochs, return_log)
#    1180             The rejection log. Returned only of return_log is True.
#    1181         """
# -> 1182         return self.fit(epochs).transform(epochs, return_log=return_log)
#    1183
#    1184     def save(self, fname, overwrite=False):
#
# c:\users\sayye\appdata\local\programs\python\python39\lib\site-packages\autoreject\autoreject.py in fit(self, epochs)
#    1002         """
#    1003         self.picks_ = _handle_picks(info=epochs.info, picks=self.picks)
# -> 1004         _check_data(epochs, picks=self.picks_, verbose=self.verbose)
# ...
